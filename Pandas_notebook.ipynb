# %% [markdown]
# #What is Pandas ?
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.
#
# ##Why Use Pandas?
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# Pandas can clean messy data sets, and make them readable and relevant.
#
# Relevant data is very important in data science.

# %%
import pandas as pd

df = pd.read_csv('matches.csv')
# read_csv function will read specified csv file there are many similar functions also like read_json , read_excel etc

df.head()      # this head() function will display the first five records of the dataset
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
print(type(df))   #this will show the type of the mentioned entity
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
list(df.columns)    #This will print the list of column  names
# Out:
# ['id',
#  'season',
#  'city',
#  'date',
#  'match_type',
#  'player_of_match',
#  'venue',
#  'team1',
#  'team2',
#  'toss_winner',
#  'toss_decision',
#  'winner',
#  'result',
#  'result_margin',
#  'target_runs',
#  'target_overs',
#  'super_over',
#  'method',
#  'umpire1',
#  'umpire2']

# %%
df.head().transpose()
# Out:
#                                            0  ...                      4
# id                                    335982  ...                 335986
# season                               2007/08  ...                2007/08
# city                               Bangalore  ...                Kolkata
# date                              2008-04-18  ...             2008-04-20
# match_type                            League  ...                 League
# player_of_match                  BB McCullum  ...              DJ Hussey
# venue                  M Chinnaswamy Stadium  ...           Eden Gardens
# team1            Royal Challengers Bangalore  ...  Kolkata Knight Riders
# team2                  Kolkata Knight Riders  ...        Deccan Chargers
# toss_winner      Royal Challengers Bangalore  ...        Deccan Chargers
# toss_decision                          field  ...                    bat
# winner                 Kolkata Knight Riders  ...  Kolkata Knight Riders
# ...

# %%
df.shape
# it will display number of records in which first value of tuple is the number of rows and the second value is the number of columns
# Out:
# (1095, 20)

# %%
df.info()
# info() function displays the detailed summary about the given dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
df[0:5]
#slicing and indexing can be used to select few rows and columns  .
#The row and column indexes always start with value 0 .
# Out:
#        id  ...         umpire2
# 0  335982  ...     RE Koertzen
# 1  335983  ...      SL Shastri
# 2  335984  ...  GA Pratapkumar
# 3  335985  ...       DJ Harper
# 4  335986  ...     K Hariharan
#
# [5 rows x 20 columns]

# %%
#Value Counts
df.city.value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Indore              9
# Navi Mumbai         9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Mohali              5
# Kochi               5
# Kanpur              4
# Kimberley           3
# East London         3
# Guwahati            3
# Nagpur              3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
#iloc
df.iloc[4:9,1:2]
# Out:
#     season
# 4  2007/08
# 5  2007/08
# 6  2007/08
# 7  2007/08
# 8  2007/08

# %%
list(df.columns)
# Out:
# ['id',
#  'season',
#  'city',
#  'date',
#  'match_type',
#  'player_of_match',
#  'venue',
#  'team1',
#  'team2',
#  'toss_winner',
#  'toss_decision',
#  'winner',
#  'result',
#  'result_margin',
#  'target_runs',
#  'target_overs',
#  'super_over',
#  'method',
#  'umpire1',
#  'umpire2']

# %%
df[['winner','target_runs']].sort_values('target_runs')[0:10]
# Out:
#                       winner  target_runs
# 429      Sunrisers Hyderabad         43.0
# 633    Kolkata Knight Riders         48.0
# 221    Kolkata Knight Riders         52.0
# 41       Chennai Super Kings         53.0
# 60          Delhi Daredevils         54.0
# 565  Rising Pune Supergiants         58.0
# 538  Rising Pune Supergiants         61.0
# 744                      NaN         63.0
# 561    Kolkata Knight Riders         66.0
# 611          Kings XI Punjab         68.0

# %%
df[['winner','target_runs']].sort_values('target_runs',ascending=False)[0:10]
# Out:
#                            winner  target_runs
# 1053          Sunrisers Hyderabad        288.0
# 1031          Sunrisers Hyderabad        278.0
# 1039        Kolkata Knight Riders        273.0
# 1058          Sunrisers Hyderabad        267.0
# 352   Royal Challengers Bangalore        264.0
# 1065                 Punjab Kings        262.0
# 1066               Delhi Capitals        258.0
# 987          Lucknow Super Giants        258.0
# 560   Royal Challengers Bangalore        249.0
# 146           Chennai Super Kings        247.0
